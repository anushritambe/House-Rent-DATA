# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('Real estate.csv')

# %%
df.shape
# Out:
# (414, 8)

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# ...

# %%
df.isnull().sum()
# Out:
# No                                        0
# X1 transaction date                       0
# X2 house age                              0
# X3 distance to the nearest MRT station    0
# X4 number of convenience stores           0
# X5 latitude                               0
# X6 longitude                              0
# Y house price of unit area                0
# dtype: int64

# %%
df.dtypes
# Out:
# No                                          int64
# X1 transaction date                       float64
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# dtype: object

# %%
df.drop('No', axis=1 , inplace=True)

# %%
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# ...

# %%
df.describe()
# Out:
#        X1 transaction date  X2 house age  \
# count           414.000000    414.000000
# mean           2013.148971     17.712560
# std               0.281967     11.392485
# min            2012.667000      0.000000
# 25%            2012.917000      9.025000
# 50%            2013.167000     16.100000
# 75%            2013.417000     28.150000
# max            2013.583000     43.800000
#
#        X3 distance to the nearest MRT station  \
# count                              414.000000
# mean                              1083.885689
# std                               1262.109595
# min                                 23.382840
# 25%                                289.324800
# 50%                                492.231300
# 75%                               1454.279000
# max                               6488.021000
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                       414.000000   414.000000    414.000000
# ...

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                                         X1 transaction date  X2 house age  \
# X1 transaction date                                1.000000      0.017549
# X2 house age                                       0.017549      1.000000
# X3 distance to the nearest MRT station             0.060880      0.025622
# X4 number of convenience stores                    0.009635      0.049593
# X5 latitude                                        0.035058      0.054420
# X6 longitude                                      -0.041082     -0.048520
# Y house price of unit area                         0.087491     -0.210567
#
#                                         X3 distance to the nearest MRT station  \
# X1 transaction date                                                   0.060880
# X2 house age                                                          0.025622
# X3 distance to the nearest MRT station                                1.000000
# ...

# %%
df1= df.copy()

# %%
X= df1.iloc[:,:-1]
y= df1.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn import metrics
mae=metrics.mean_absolute_error(y_test,y_pred)
mse=metrics.mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
print('mae :', mae,'mse :', mse,'rmse :', rmse)
# Out:
# mae : 5.343030944662945 mse : 45.01050719519162 rmse : 6.7089870468791055

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.7034608498767498

# %% [markdown]
# ### Feature Scaling

# %%
df2=df.copy()

# %%
X1= df2.iloc[:,:-1]
y1= df2.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
X1_train, X1_test, y1_train, y1_test=train_test_split(X1,y1,test_size=0.2,random_state=1)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X1_train=sc.fit_transform(X1_train)
X1_test = sc.transform(X1_test)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics
mae=metrics.mean_absolute_error(y_test,y_pred)
mse=metrics.mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
print('mae :', mae,'mse :', mse,'rmse :', rmse)
# Out:
# mae : 5.343030944662945 mse : 45.01050719519162 rmse : 6.7089870468791055

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.7034608498767498

# %%
X1
# Out:
#      X1 transaction date  X2 house age  \
# 0               2012.917          32.0
# 1               2012.917          19.5
# 2               2013.583          13.3
# 3               2013.500          13.3
# 4               2012.833           5.0
# ..                   ...           ...
# 409             2013.000          13.7
# 410             2012.667           5.6
# 411             2013.250          18.8
# 412             2013.000           8.1
# 413             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# 4                                 390.56840                                5
# ...

# %%
plt.plot(df['X1 transaction date'],df['Y house price of unit area'])

# %%
df['date']=df['X1 transaction date']
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area      date
# 0                        37.9  2012.917
# 1                        42.2  2012.917
# ...

# %%
df['date']= round(df['date'],1)

# %%
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area    date
# 0                        37.9  2012.9
# 1                        42.2  2012.9
# ...

# %%
import math
a=2012.2
year = int(a)
frac= a-year
frac
# Out:
# 0.20000000000004547

# %%
from decimal import Decimal, ROUND_DOWN
Decimal(frac).quantize(Decimal('.1'), rounding=ROUND_DOWN)
# Out:
# Decimal('0.2')

# %%
df['date']=df["date"].astype(str)

# %%
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area    date
# 0                        37.9  2012.9
# 1                        42.2  2012.9
# ...

# %%
df['date'][0]
# Out:
# '2012.9'

# %%
for i in df['date']:
    print(i)
# Out:
# 2012.9
# 2012.9
# 2013.6
# 2013.5
# 2012.8
# 2012.7
# 2012.7
# 2013.4
# 2013.5
# 2013.4
# 2013.1
# 2013.3
# 2012.9
# 2012.7
# 2013.5
# 2013.6
# 2013.2
# 2012.8
# 2013.4
# 2012.7
# 2013.4
# 2013.4
# 2012.9
# 2013.1
# 2013.0
# 2013.1
# 2012.7
# 2013.2
# 2013.5
# 2013.1
# 2013.5
# 2012.8
# 2012.8
# 2013.2
# 2012.8
# 2013.5
# 2012.9
# 2013.2
# 2012.7
# 2013.2
# 2013.0
# 2013.5
# 2013.4
# 2012.8
# 2013.6
# 2013.1
# 2013.4
# 2013.6
# 2013.4
# 2012.7
# 2013.4
# 2013.1
# 2013.6
# 2013.1
# 2013.1
# 2012.8
# 2013.4
# 2012.9
# 2013.5
# 2013.1
# 2013.4
# 2013.5
# 2012.9
# 2013.6
# 2013.3
# 2013.4
# 2013.0
# 2013.5
# 2013.4
# 2012.8
# 2013.6
# 2013.1
# 2013.6
# 2013.2
# 2012.9
# 2013.5
# 2013.6
# 2012.8
# 2012.9
# 2013.0
# 2013.5
# 2013.0
# 2013.1
# 2012.9
# 2013.1
# 2012.8
# 2012.8
# 2013.6
# 2012.9
# 2013.5
# 2012.8
# 2013.2
# 2012.9
# 2012.9
# 2012.9
# 2012.9
# 2013.4
# 2013.1
# 2013.4
# 2013.4
# 2013.5
# 2012.8
# 2013.1
# 2012.8
# 2012.7
# 2012.8
# 2013.1
# 2013.3
# 2013.4
# 2013.6
# 2013.1
# ...

# %%
df['date']=df['date'].str.split(".",0)

# %%
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area       date
# 0                        37.9  [2012, 9]
# 1                        42.2  [2012, 9]
# ...

# %%
df['year']=df['date'].str.get(0)

# %%
df['month']=df['date'].str.get(1)

# %%
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area       date  year month
# 0                        37.9  [2012, 9]  2012     9
# ...

# %%
df['month']=df["month"].astype(int)

# %%
df['month']=df['month']+1

# %%
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area       date  year  month
# 0                        37.9  [2012, 9]  2012     10
# ...

# %%
df['year']=df["year"].astype(int)

# %%
df.head()
# Out:
#    X1 transaction date  X2 house age  X3 distance to the nearest MRT station  \
# 0             2012.917          32.0                                84.87882
# 1             2012.917          19.5                               306.59470
# 2             2013.583          13.3                               561.98450
# 3             2013.500          13.3                               561.98450
# 4             2012.833           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area       date  year  month
# 0                        37.9  [2012, 9]  2012     10
# ...

# %%
df['month'].unique()
# Out:
# array([10,  7,  6,  9,  8,  5,  2,  4,  3,  1])

# %%
df.drop(['X1 transaction date','date'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area  year  month
# 0                        37.9  2012     10
# 1                        42.2  2012     10
# 2                        47.3  2013      7
# 3                        54.8  2013      6
# ...

# %%
df['year'].unique()
# Out:
# array([2012, 2013])

# %%
df['dateInt']=df['year'].astype(str) + df['month'].astype(str).str.zfill(2)
df['Date'] = pd.to_datetime(df['dateInt'], format='%Y%m')

# %%
df.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area  year  month dateInt       Date
# 0                        37.9  2012     10  201210 2012-10-01
# 1                        42.2  2012     10  201210 2012-10-01
# 2                        47.3  2013      7  201307 2013-07-01
# ...

# %%
df['date'] = pd.to_datetime(df['Date']).dt.to_period('M')
df.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area  year  month dateInt       Date     date
# 0                        37.9  2012     10  201210 2012-10-01  2012-10
# 1                        42.2  2012     10  201210 2012-10-01  2012-10
# ...

# %%
df.drop(['year','month','dateInt','Date'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area     date
# 0                        37.9  2012-10
# 1                        42.2  2012-10
# 2                        47.3  2013-07
# 3                        54.8  2013-06
# 4                        43.1  2012-09

# %%
df.dtypes
# Out:
# X2 house age                                float64
# X3 distance to the nearest MRT station      float64
# X4 number of convenience stores               int64
# X5 latitude                                 float64
# X6 longitude                                float64
# Y house price of unit area                  float64
# date                                      period[M]
# dtype: object

# %%
sns.pairplot(df)

# %%
df.describe()
# Out:
#        X2 house age  X3 distance to the nearest MRT station  \
# count    414.000000                              414.000000
# mean      17.712560                             1083.885689
# std       11.392485                             1262.109595
# min        0.000000                               23.382840
# 25%        9.025000                              289.324800
# 50%       16.100000                              492.231300
# 75%       28.150000                             1454.279000
# max       43.800000                             6488.021000
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                       414.000000   414.000000    414.000000
# mean                          4.094203    24.969030    121.533361
# std                           2.945562     0.012410      0.015347
# min                           0.000000    24.932070    121.473530
# 25%                           1.000000    24.963000    121.528085
# ...

# %%
df3=df.copy()

# %%
starting_date= min(df3['date'])

# %%
starting_date
# Out:
# Period('2012-08', 'M')

# %%
df3['months']=df3['date']-starting_date

# %%
df3.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area     date            months
# 0                        37.9  2012-10   <2 * MonthEnds>
# 1                        42.2  2012-10   <2 * MonthEnds>
# 2                        47.3  2013-07  <11 * MonthEnds>
# ...

# %%
df3.dtypes
# Out:
# X2 house age                                float64
# X3 distance to the nearest MRT station      float64
# X4 number of convenience stores               int64
# X5 latitude                                 float64
# X6 longitude                                float64
# Y house price of unit area                  float64
# date                                      period[M]
# months                                       object
# dtype: object

# %%
df3['months']=df3['months'].astype('str')

# %%
df3['months']=df3['months'].str.split(" ",0)

# %%
df3.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area     date                months
# 0                        37.9  2012-10   [<2, *, MonthEnds>]
# 1                        42.2  2012-10   [<2, *, MonthEnds>]
# 2                        47.3  2013-07  [<11, *, MonthEnds>]
# ...

# %%
df3['Month']=df3['months'].str.get(0)

# %%
df3.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area     date                months       Month
# 0                        37.9  2012-10   [<2, *, MonthEnds>]          <2
# 1                        42.2  2012-10   [<2, *, MonthEnds>]          <2
# ...

# %%
df3['Month']=df3['Month'].str.split("<",0)

# %%
df3.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area     date                months          Month
# 0                        37.9  2012-10   [<2, *, MonthEnds>]          [, 2]
# 1                        42.2  2012-10   [<2, *, MonthEnds>]          [, 2]
# ...

# %%
df3['Months']=df3['Month'].str.get(1)

# %%
df3.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area     date                months          Month  \
# 0                        37.9  2012-10   [<2, *, MonthEnds>]          [, 2]
# 1                        42.2  2012-10   [<2, *, MonthEnds>]          [, 2]
# ...

# %%
df3['Months'].unique()
# Out:
# array(['2', '11', '10', 'MonthEnd>', '0', '9', '6', '8', '7', '5'],
#       dtype=object)

# %%
df3['Months'].replace(to_replace='MonthEnd>', value='1',inplace= True)

# %%
df3.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area     date                months          Month  \
# 0                        37.9  2012-10   [<2, *, MonthEnds>]          [, 2]
# 1                        42.2  2012-10   [<2, *, MonthEnds>]          [, 2]
# ...

# %%
data=df3.drop(['months','date','Month'],axis=1)

# %%
data.head()
# Out:
#    X2 house age  X3 distance to the nearest MRT station  \
# 0          32.0                                84.87882
# 1          19.5                               306.59470
# 2          13.3                               561.98450
# 3          13.3                               561.98450
# 4           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area Months
# 0                        37.9      2
# 1                        42.2      2
# 2                        47.3     11
# 3                        54.8     10
# 4                        43.1      1

# %%
data['Months']=data['Months'].astype(int)

# %%
data.dtypes
# Out:
# X2 house age                              float64
# X3 distance to the nearest MRT station    float64
# X4 number of convenience stores             int64
# X5 latitude                               float64
# X6 longitude                              float64
# Y house price of unit area                float64
# Months                                      int32
# dtype: object

# %%
sns.pairplot(data)

# %%
month = df3['Months']
datan = data.drop(columns=['Months'])
datan.insert(loc=0, column='Months', value=month)

# %%
datan.head()
# Out:
#   Months  X2 house age  X3 distance to the nearest MRT station  \
# 0      2          32.0                                84.87882
# 1      2          19.5                               306.59470
# 2     11          13.3                               561.98450
# 3     10          13.3                               561.98450
# 4      1           5.0                               390.56840
#
#    X4 number of convenience stores  X5 latitude  X6 longitude  \
# 0                               10     24.98298     121.54024
# 1                                9     24.98034     121.53951
# 2                                5     24.98746     121.54391
# 3                                5     24.98746     121.54391
# 4                                5     24.97937     121.54245
#
#    Y house price of unit area
# 0                        37.9
# 1                        42.2
# 2                        47.3
# 3                        54.8
# 4                        43.1

# %%
X= datan.iloc[:,:-1].values
y= datan.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X,y,test_size=0.2,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
from sklearn import metrics
mae=metrics.mean_absolute_error(y_test,y_pred)
mse=metrics.mean_squared_error(y_test,y_pred)
rmse=np.sqrt(mse)
print('mae :', mae,'mse :', mse,'rmse :', rmse)
# Out:
# mae : 5.336684848381545 mse : 45.08053825700007 rmse : 6.71420421621208

# %% [markdown]
# Changed date time into proper format but still we get same values

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print('r2 score for perfect model is', r2)
# Out:
# r2 score for perfect model is 0.7029994697936317

# %%
datan.to_csv('rent.csv')
